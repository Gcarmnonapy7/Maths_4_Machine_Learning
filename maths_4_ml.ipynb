# %% [markdown]
# <a href="https://colab.research.google.com/github/Gcarmnonapy7/Maths_4_Machine_Learning/blob/main/maths_4_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def gram_schmidt(input_matrix,tolerance=1e-5):
  """
  Compute an orthonormal basis from the columns of a matrix using the Gram-Schmidt process

  params :
  input_matrix -> (n,m) array
       The input vectors are the columns of the input_matrix
  tolerance -> float
       Threshold for linear dependence
  output :
       orthonormal_basis : (n, k) array
            Matrix with orthonormal columns
       upper_triangular : (k, m) array
            Coefficients matrix (R in QR decomposition)
  """

  pass
